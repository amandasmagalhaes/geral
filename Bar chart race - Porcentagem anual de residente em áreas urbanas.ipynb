# %% [markdown]
# <a href="https://colab.research.google.com/github/amandasmagalhaes/geral/blob/main/Bar%20chart%20race%20-%20Porcentagem%20anual%20de%20residente%20em%20%C3%A1reas%20urbanas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Pacotes

import pandas as pd

# !pip install -q bar_chart_race
import bar_chart_race as bcr

# !pip install -q ffmpeg
import ffmpeg
# Out:
#      |████████████████████████████████| 163kB 17.9MB/s
# ...

# %%
#Dataset

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Análises/porcentagem residente áreas urbanas 2.csv', encoding= 'unicode_escape', sep=';').set_index('Ano')

# %%
#Primeiras linhas

df.head()
# Out:
#       África  Ásia  Europa  ...  BRASIL  América do Norte  Oceânia
# Ano                         ...
# 1950    14.3  17.5    51.7  ...    36.2              63.9     62.5
# 1951    14.7  17.9    52.3  ...    37.1              64.5     63.0
# 1952    15.1  18.2    52.8  ...    38.1              65.2     63.5
# 1953    15.5  18.6    53.4  ...    39.1              65.8     63.9
# 1954    15.9  18.9    53.9  ...    40.1              66.4     64.3
#
# [5 rows x 7 columns]

# %%
#Figura

bcr.bar_chart_race(df,
                   title='Porcentagem anual da população residente em áreas urbanas, por região e no Brasil, 1950-2050',
                   title_size=7,
                   period_length=300,
                   cmap='paired',
                   period_fmt='{x:.0f}', 
                   perpendicular_bar_func='mean', 
                   figsize=(5, 3)
                   )
# Out:
# <video width="840" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...
